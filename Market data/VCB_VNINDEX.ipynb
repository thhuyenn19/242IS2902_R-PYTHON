# %%
from google.colab import drive
import os
drive.mount('/content/drive')
path="/content/drive/MyDrive/Colab Notebooks"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git clone https://github.com/phamdinhkhanh/vnquant
# %cd vnquant
# !python setup.py install
# Out:
# fatal: destination path 'vnquant' already exists and is not an empty directory.
# /content/vnquant/vnquant
# python3: can't open file '/content/vnquant/vnquant/setup.py': [Errno 2] No such file or directory

# %%
# %cd ..
# !rm -rf vnquant
# !ls
# Out:
# /content/vnquant
# build  dist  README.md	requirements.txt  setup.py  test.py  vnquant.egg-info

# %%
# !pip freeze | grep vnquant
# Out:
# DEPRECATION: Loading egg at /usr/local/lib/python3.11/dist-packages/pypandoc-1.15-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /usr/local/lib/python3.11/dist-packages/bs4-0.0.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /usr/local/lib/python3.11/dist-packages/vnquant-0.1.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# vnquant==0.1.2

# %%
# !pip install --upgrade --force-reinstall vnquant
# Out:
# DEPRECATION: Loading egg at /usr/local/lib/python3.11/dist-packages/pypandoc-1.15-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /usr/local/lib/python3.11/dist-packages/bs4-0.0.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /usr/local/lib/python3.11/dist-packages/vnquant-0.1.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# ERROR: Could not find a version that satisfies the requirement vnquant (from versions: none)
# ...

# %%
import vnquant
vnquant.__version__
# Out:
# '0.1.2'

# %%
import vnquant.data as dt

loader = dt.DataLoader(symbols="VCB",
           start="2019-12-31",
           end="2025-1-1",
           minimal=True,
           data_source="cafe")

data = loader.download()
# Out:
# [2025-03-28 09:47:21] - Assitant - INFO      - download - line 34 - Start downloading data symbols ['VCB'] from CAFEF, start: 31/12/2019, end: 01/01/2025!
# [2025-03-28 09:47:22] - Assitant - INFO      - download_one - line 94 - data VCB from 2019-12-31 to 2025-01-01 have already cloned!

# %%
data.to_csv("/content/drive/MyDrive/Colab Notebooks/VCB_stock_data.csv", index=True)

# %%
import pandas as pd
data = pd.DataFrame(data)

# %%
import pandas as pd
data_from_csv = pd.read_csv("/content/drive/MyDrive/Colab Notebooks//VCB_stock_data.csv")
print(data_from_csv.head())
# Out:
#    Attributes code  high   low  open close adjust volume_match     value_match
# 0     Symbols  VCB   VCB   VCB   VCB   VCB    VCB          VCB             VCB
# 1        date  NaN   NaN   NaN   NaN   NaN    NaN          NaN             NaN
# 2  2025-03-28  VCB  65.7  64.8  65.5  64.8   64.8    1650600.0  107522000000.0
# 3  2024-12-31  VCB  92.4  91.2  92.2  91.2   61.0    2374000.0  217412000000.0
# 4  2024-12-30  VCB  92.5  92.0  92.2  92.0  61.54    1706700.0  157327000000.0

# %%
data = data_from_csv.drop([0, 1,2])  # Xóa dòng đầu tiên (0) và dòng thứ hai (1)
data.rename(columns={'Attributes': 'date'}, inplace=True)
data.reset_index(drop=True, inplace=True)

# %%
data.head(10)
# Out:
#          date code  high   low  open close adjust volume_match     value_match
# 0  2024-12-31  VCB  92.4  91.2  92.2  91.2   61.0    2374000.0  217412000000.0
# 1  2024-12-30  VCB  92.5  92.0  92.2  92.0  61.54    1706700.0  157327000000.0
# 2  2024-12-27  VCB  93.0  92.2  92.5  92.2  61.67    1639900.0  151654000000.0
# 3  2024-12-26  VCB  92.8  92.0  92.5  92.1  61.61    2202900.0  203219000000.0
# 4  2024-12-25  VCB  93.8  92.2  92.2  92.4  61.81    1827700.0  169706000000.0
# 5  2024-12-24  VCB  92.8  92.0  92.7  92.1  61.61    1024300.0   94462000000.0
# 6  2024-12-23  VCB  92.8  92.4  92.6  92.4  61.81     707200.0   65485000000.0
# 7  2024-12-20  VCB  92.9  92.3  92.4  92.5  61.87    1245900.0  115258000000.0
# 8  2024-12-19  VCB  92.8  92.2  92.8  92.4  61.81    1869700.0  172939000000.0
# 9  2024-12-18  VCB  93.3  93.0  93.0  93.1  62.27     530300.0   49400000000.0

# %%
import vnquant.data as dt

loader = dt.DataLoader(symbols="VNINDEX",
           start="2019-12-31",
           end="2025-01-01",
           minimal=True,
           data_source="cafe")

data2 = loader.download()
# Out:
# [2025-03-28 12:11:04] - Assitant - INFO      - download - line 34 - Start downloading data symbols ['VNINDEX'] from CAFEF, start: 31/12/2019, end: 01/01/2025!
# [2025-03-28 12:11:05] - Assitant - INFO      - download_one - line 94 - data VNINDEX from 2019-12-31 to 2025-01-01 have already cloned!

# %%
data2.to_csv("/content/drive/MyDrive/Colab Notebooks/VNIndex_data.csv", index=True)

# %%
import pandas as pd
data2 = pd.DataFrame(data2)

# %%
import pandas as pd
data_from_csv2 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/VNIndex_data.csv")
print(data_from_csv2.head())
# Out:
#    Attributes     code     high      low     open    close   adjust  \
# 0     Symbols  VNINDEX  VNINDEX  VNINDEX  VNINDEX  VNINDEX  VNINDEX
# 1        date      NaN      NaN      NaN      NaN      NaN      NaN
# 2  2024-12-31  VNINDEX  1272.46  1266.78  1272.25  1266.78  1266.78
# 3  2024-12-30  VNINDEX  1274.15  1268.77  1273.75  1272.02  1272.02
# 4  2024-12-27  VNINDEX  1277.89  1272.23  1275.56  1275.14  1275.14
#
#   volume_match       value_match
# 0      VNINDEX           VNINDEX
# 1          NaN               NaN
# 2  407171783.0   9570643132850.0
# 3  452946957.0  10012327206260.0
# 4  579882989.0  13286059082390.0

# %%
data2 = data_from_csv2.drop([0, 1])  # Xóa dòng đầu tiên (0) và dòng thứ hai (1)
data2.rename(columns={'Attributes': 'date'}, inplace=True)
data2.reset_index(drop=True, inplace=True)

# %%
data2.head(10)
# Out:
#          date     code     high      low     open    close   adjust  \
# 0  2024-12-31  VNINDEX  1272.46  1266.78  1272.25  1266.78  1266.78
# 1  2024-12-30  VNINDEX  1274.15  1268.77  1273.75  1272.02  1272.02
# 2  2024-12-27  VNINDEX  1277.89  1272.23  1275.56  1275.14  1275.14
# 3  2024-12-26  VNINDEX  1277.17  1271.99  1275.68  1272.87  1272.87
# 4  2024-12-25  VNINDEX  1283.09  1261.87  1262.03  1274.04  1274.04
# 5  2024-12-24  VNINDEX  1263.05  1253.78  1263.03  1260.36  1260.36
# 6  2024-12-23  VNINDEX   1265.2  1261.62  1262.45  1262.76  1262.76
# 7  2024-12-20  VNINDEX   1259.0   1253.9   1255.6   1257.5   1257.5
# 8  2024-12-19  VNINDEX  1259.76  1249.39   1256.9  1254.67  1254.67
# 9  2024-12-18  VNINDEX  1266.53  1261.49  1262.57   1266.0   1266.0
#
#   volume_match       value_match
# 0  407171783.0   9570643132850.0
# 1  452946957.0  10012327206260.0
# 2  579882989.0  13286059082390.0
# 3  502071890.0  10640383260640.0
# 4  724345690.0  16511995715950.0
# ...
